# %%
from PIL import Image
from haishoku.haishoku import Haishoku

path = 'pics/matplotlib_o.png'
palette = Haishoku.getPalette(path)
im = Image.open(path)
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1138x1056 at 0x2153DEAA820>

# %%
c = im.getcolors(maxcolors=im.size[0] * im.size[1])
